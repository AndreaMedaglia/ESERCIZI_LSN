# %% [markdown]
# # EXERCISE 09
#
# ## Cities in the [0,1]x[0,1] square

# %% [markdown]
# ## Best Path

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, y = np.loadtxt("./Exercise_10/Configuration.dat", usecols=(0,1), unpack='true')
plt.plot(x, y, 'o-')
plt.xlabel('')
plt.ylabel('')
plt.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, y = np.loadtxt("./Exercise_9/Best_l_s.dat", usecols=(0,1), unpack='true')
plt.plot(x, y)
plt.xlabel('')
plt.ylabel('')
plt.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, y = np.loadtxt("./Exercise_9/Average_l_s.dat", usecols=(0,1), unpack='true')
plt.plot(x, y)
plt.xlabel('')
plt.ylabel('')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Best Path

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, y = np.loadtxt("./Exercise_9/Best_path_c.dat", usecols=(0,1), unpack='true')
plt.plot(x, y, 'o-')
plt.xlabel('')
plt.ylabel('')
plt.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, y = np.loadtxt("./Exercise_9/Best_l_c.dat", usecols=(0,1), unpack='true')
plt.plot(x, y)
plt.xlabel('')
plt.ylabel('')
plt.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, y = np.loadtxt("./Exercise_9/Average_l_c.dat", usecols=(0,1), unpack='true')
plt.plot(x, y)
plt.xlabel('')
plt.ylabel('')
plt.grid(True)
plt.show()
