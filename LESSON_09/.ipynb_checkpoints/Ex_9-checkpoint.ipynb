# %% [markdown]
# # EXERCISE 08
#
# ## Total Energy

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, y = np.loadtxt("./Exercise_8.1/Energy_.txt", usecols=(0,1), unpack='true')
plt.errorbar(x,f,yerr=error)
plt.xlabel('')
plt.ylabel('')
plt.grid(True)
plt.show()
